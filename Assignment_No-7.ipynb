# %%
# !pip install pandas

# %%
import pandas as pd

# %%
#dir(pd)

# %%
#Printing the data in csv file
df = pd.read_csv('compensation data.csv')
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
# Convert data to list of lists
data_list = df.values.tolist()  
data_list
# Out:
# [[6.1, True, False, True, 'Scikit-learn', 124267],
#  [12.3, True, True, True, 'Scikit-learn', 236889],
#  [2.2, True, False, False, nan, 74321],
#  [2.7, False, False, True, nan, 62593],
#  [1.2, True, False, False, 'Scikit-learn', 36288],
#  [1.0, True, False, False, 'PyTorch', 61302],
#  [1.8, False, False, False, nan, 68984],
#  [6.1, True, False, False, 'TensorFlow', 18858],
#  [4.5, True, False, True, 'Scikit-learn', 55418],
#  [1.1, True, False, True, 'TensorFlow', 614],
#  [2.7, True, True, True, nan, 70564],
#  [0.93, True, True, False, 'Scikit-learn', 55525],
#  [0.32, True, False, False, nan, 61005],
#  [9.9, True, False, True, 'Scikit-learn', 2846],
#  [0.78, True, False, False, 'TensorFlow', 21],
#  [13.5, True, False, False, 'Scikit-learn', 14699],
#  [26.5, True, False, True, 'Scikit-learn', 2110],
#  [1.5, True, False, True, 'Scikit-learn', 620],
#  [3.4, True, False, True, 'PyTorch', 73527],
#  [0.6, False, False, False, nan, 6992],
# ...

# %%
#first 5 rows of the data
df.head(5)
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288

# %%
#Print headings into list
df.columns.tolist()
# Out:
# ['experience_coding',
#  'python_user',
#  'r_user',
#  'sql_user',
#  'most_used',
#  'compensation']

# %%
# Convert only data without headers to a list of lists
survey = df.values.tolist()  
survey
# Out:
# [[6.1, True, False, True, 'Scikit-learn', 124267],
#  [12.3, True, True, True, 'Scikit-learn', 236889],
#  [2.2, True, False, False, nan, 74321],
#  [2.7, False, False, True, nan, 62593],
#  [1.2, True, False, False, 'Scikit-learn', 36288],
#  [1.0, True, False, False, 'PyTorch', 61302],
#  [1.8, False, False, False, nan, 68984],
#  [6.1, True, False, False, 'TensorFlow', 18858],
#  [4.5, True, False, True, 'Scikit-learn', 55418],
#  [1.1, True, False, True, 'TensorFlow', 614],
#  [2.7, True, True, True, nan, 70564],
#  [0.93, True, True, False, 'Scikit-learn', 55525],
#  [0.32, True, False, False, nan, 61005],
#  [9.9, True, False, True, 'Scikit-learn', 2846],
#  [0.78, True, False, False, 'TensorFlow', 21],
#  [13.5, True, False, False, 'Scikit-learn', 14699],
#  [26.5, True, False, True, 'Scikit-learn', 2110],
#  [1.5, True, False, True, 'Scikit-learn', 620],
#  [3.4, True, False, True, 'PyTorch', 73527],
#  [0.6, False, False, False, nan, 6992],
# ...

# %%
# Print first column by index position
df.iloc[:, 0]
# Out:
# 0         6.1
# 1        12.3
# 2         2.2
# 3         2.7
# 4         1.2
#          ...
# 25968     1.9
# 25969     1.4
# 25970     0.0
# 25971     9.4
# 25972     0.0
# Name: experience_coding, Length: 25973, dtype: float64

# %%
# Print first row by index position
df.iloc[0].tolist()
# Out:
# [6.1, True, False, True, 'Scikit-learn', 124267]

# %%
# Access the element at index 5 in each column
for column in df:
        print(type(df[column].iloc[5]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.bool_'>
# <class 'numpy.bool_'>
# <class 'numpy.bool_'>
# <class 'str'>
# <class 'numpy.int64'>

# %%
df[:3]
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
#
#    compensation
# 0        124267
# 1        236889
# 2         74321

# %%
df.iloc[4].tolist()
# Out:
# [1.2, True, False, False, 'Scikit-learn', 36288]

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1, 2, 3]).sum()
# Out:
# 6

# %%
listt = pd.Series([1, 2, 3]).tolist()
listt
# Out:
# [1, 2, 3]

# %%
sum(listt)
# Out:
# 6

# %%
df.iloc[:, 5]
# Out:
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288
#           ...
# 25968     15800
# 25969     62456
# 25970       923
# 25971     60609
# 25972       493
# Name: compensation, Length: 25973, dtype: int64

# %%
# Check first few rows
print(df.iloc[:, 1].head())  
print(df.iloc[:, 2].head())
print(df.iloc[:, 3].head())
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: python_user, dtype: bool
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: r_user, dtype: bool
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: sql_user, dtype: bool

# %%
# Check first few rows
print(df.iloc[:, 1].head().tolist())  
print(df.iloc[:, 2].head().tolist())
print(df.iloc[:, 3].head().tolist())
# Out:
# [True, True, True, False, True]
# [False, True, False, False, False]
# [True, True, False, True, False]

# %%
# Check counts of True/False
print(df.iloc[:, 1].value_counts())  
print(df.iloc[:, 2].value_counts())
print(df.iloc[:, 3].value_counts())
# Out:
# python_user
# True     21860
# False     4113
# Name: count, dtype: int64
# r_user
# False    20638
# True      5335
# Name: count, dtype: int64
# sql_user
# False    15216
# True     10757
# Name: count, dtype: int64

# %%
# Check counts of True/False
print(df.iloc[:, 1].value_counts().tolist())  
print(df.iloc[:, 2].value_counts().tolist())
print(df.iloc[:, 3].value_counts().tolist())
# Out:
# [21860, 4113]
# [20638, 5335]
# [15216, 10757]

# %%
python_user = df.iloc[:, 1].sum()
r_user = df.iloc[:, 2].sum()
sql_user = df.iloc[:, 3].sum()

print(python_user)  # Output: 21860
print(r_user)       # Output: 5335
print(sql_user)     # Output: 10757
# Out:
# 21860
# 5335
# 10757

# %%
for index, row in df.iterrows():
    # First column
    exp = row.iloc[0]   
    # Last column
    comp = row.iloc[-1] 
    
    print(exp)
# Out:
# 6.1
# 12.3
# 2.2
# 2.7
# 1.2
# 1.0
# 1.8
# 6.1
# 4.5
# 1.1
# 2.7
# 0.93
# 0.32
# 9.9
# 0.78
# 13.5
# 26.5
# 1.5
# 3.4
# 0.6
# 0.95
# 4.6
# 2.8
# 28.2
# 1.4
# 4.8
# 0.37
# 4.5
# 4.4
# 0.69
# 1.5
# 9.6
# 0.31
# 3.5
# 1.0
# 0.2
# 0.39
# 5.0
# 4.0
# 0.47
# 8.1
# 1.8
# 17.1
# 1.4
# 1.3
# 3.1
# 0.26
# 2.1
# 4.4
# 5.2
# 0.7
# 0.69
# 1.3
# 1.5
# 2.2
# 6.3
# 2.9
# 1.2
# 1.5
# 1.8
# 0.91
# 4.5
# 1.6
# 0.27
# 2.6
# 1.7
# 0.74
# 2.7
# 0.99
# 24.8
# 0.32
# 3.5
# 5.7
# 22.0
# 9.9
# 3.9
# 20.5
# 0.81
# 9.8
# 1.5
# 12.3
# 6.6
# 2.1
# 2.5
# 0.0
# 1.7
# 5.3
# 1.4
# 1.5
# 28.2
# 0.97
# 1.1
# 7.0
# 1.0
# 0.71
# 9.3
# 1.7
# 20.5
# 0.75
# 0.98
# 0.8
# 1.3
# 0.36
# 1.2
# 8.6
# 18.4
# 2.7
# 24.3
# 0.94
# 1.4
# 3.3
# 0.93
# 2.3
# 0.59
# 1.2
# 8.5
# 3.3
# 21.1
# 1.2
# 12.2
# 3.8
# 4.3
# 13.1
# 24.3
# 1.6
# 2.9
# 9.4
# 7.7
# 0.3
# 9.0
# 4.2
# 1.9
# 8.3
# 0.21
# 18.8
# 9.3
# 1.8
# 2.8
# 2.4
# 15.3
# 3.9
# 0.3
# 0.8
# 0.79
# 11.1
# 0.24
# 19.7
# 8.5
# 0.26
# 0.75
# 24.4
# 6.8
# 4.4
# 3.2
# 0.84
# 16.0
# 4.9
# ...

# %%
# First column
experience = df.iloc[:, 0].tolist()

# Last column
compensation = df.iloc[:, -1].tolist()

# %%
print(experience)
# Out:
# [6.1, 12.3, 2.2, 2.7, 1.2, 1.0, 1.8, 6.1, 4.5, 1.1, 2.7, 0.93, 0.32, 9.9, 0.78, 13.5, 26.5, 1.5, 3.4, 0.6, 0.95, 4.6, 2.8, 28.2, 1.4, 4.8, 0.37, 4.5, 4.4, 0.69, 1.5, 9.6, 0.31, 3.5, 1.0, 0.2, 0.39, 5.0, 4.0, 0.47, 8.1, 1.8, 17.1, 1.4, 1.3, 3.1, 0.26, 2.1, 4.4, 5.2, 0.7, 0.69, 1.3, 1.5, 2.2, 6.3, 2.9, 1.2, 1.5, 1.8, 0.91, 4.5, 1.6, 0.27, 2.6, 1.7, 0.74, 2.7, 0.99, 24.8, 0.32, 3.5, 5.7, 22.0, 9.9, 3.9, 20.5, 0.81, 9.8, 1.5, 12.3, 6.6, 2.1, 2.5, 0.0, 1.7, 5.3, 1.4, 1.5, 28.2, 0.97, 1.1, 7.0, 1.0, 0.71, 9.3, 1.7, 20.5, 0.75, 0.98, 0.8, 1.3, 0.36, 1.2, 8.6, 18.4, 2.7, 24.3, 0.94, 1.4, 3.3, 0.93, 2.3, 0.59, 1.2, 8.5, 3.3, 21.1, 1.2, 12.2, 3.8, 4.3, 13.1, 24.3, 1.6, 2.9, 9.4, 7.7, 0.3, 9.0, 4.2, 1.9, 8.3, 0.21, 18.8, 9.3, 1.8, 2.8, 2.4, 15.3, 3.9, 0.3, 0.8, 0.79, 11.1, 0.24, 19.7, 8.5, 0.26, 0.75, 24.4, 6.8, 4.4, 3.2, 0.84, 16.0, 4.9, 8.3, 6.6, 4.0, 23.9, 27.0, 0.91, 2.2, 13.9, 3.4, 1.4, 6.6, 2.6, 8.5, 28.2, 2.7, 8.6, 2.9, 2.6, 7.5, 1.3, 16.2, 2.7, 1.8, 7.1, 1.9, 0.41, 2.3, 11.8, 4.0, 5.4, 
# ...

# %%
print(experience[:10])
# Out:
# [6.1, 12.3, 2.2, 2.7, 1.2, 1.0, 1.8, 6.1, 4.5, 1.1]

# %%
print(compensation)
# Out:
# [124267, 236889, 74321, 62593, 36288, 61302, 68984, 18858, 55418, 614, 70564, 55525, 61005, 2846, 21, 14699, 2110, 620, 73527, 6992, 22311, 1377, 69174, 117636, 65937, 27856, 903, 50501, 482, 70407, 8690, 114648, 73454, 8075, 59151, 70112, 70183, 64502, 2521, 63616, 59849, 31516, 18582, 4187, 64405, 114807, 632, 61157, 1194, 28955, 56553, 75177, 28009, 67074, 50059, 7624, 74321, 671, 837, 2011, 62937, 685, 41615, 52572, 51856, 411, 152, 8181, 2708, 55041, 68412, 6141, 3979, 3760, 57465, 3864, 488487, 24393, 68624, 70796, 236889, 57861, 21055, 59167, 55882, 73802, 21206, 79803, 73043, 268191, 14298, 68805, 56003, 73664, 434, 52109, 10284, 43906, 67971, 58465, 64488, 7709, 1957, 4131, 26022, 29926, 62593, 109543, 107644, 1047, 59909, 68344, 54427, 70930, 50835, 14151, 11681, 71808, 70991, 31626, 52416, 288146, 65143, 34866, 186, 60065, 40336, 115654, 431, 59814, 45413, 4196, 55751, 61912, 49478, 29139, 67272, 70264, 264, 14853, 55482, 26, 250, 66025, 55906, 63754, 86855, 63242, 70448, 
# ...

# %%
print(compensation[:10])
# Out:
# [124267, 236889, 74321, 62593, 36288, 61302, 68984, 18858, 55418, 614]

# %%
# Minimum experience
print(df.iloc[:, 0].min())  

# Maximum experience
print(df.iloc[:, 0].max())
# Out:
# 0.0
# 30.0

# %%
average_experience = df.iloc[:, 0].mean()  
print(average_experience)
# Out:
# 5.297231740653754

# %%
# Minimum compensation
print(df.iloc[:, 5].min())  

# Maximum compensation
print(df.iloc[:, 5].max())
# Out:
# 0
# 1492951

# %%
average_experience = df.iloc[:, 5].mean()  
print(average_experience)
# Out:
# 53252.81696377007

# %%
def categorize_experience(years):
    if years < 5:
        return "< 5 Years"
    elif years < 10:
        return "5-10 Years"
    elif years < 15:
        return "10-15 Years"
    elif years < 20:
        return "15-20 Years"
    elif years < 25:
        return "20-25 Years"
    else:
        return "25+ Years"

df["Experience_Category"] = df.iloc[:, 0].apply(categorize_experience)

df.head()
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation Experience_Category
# 0        124267          5-10 Years
# 1        236889         10-15 Years
# 2         74321           < 5 Years
# 3         62593           < 5 Years
# 4         36288           < 5 Years

# %%
survey[:10]
# Out:
# [[6.1, True, False, True, 'Scikit-learn', 124267],
#  [12.3, True, True, True, 'Scikit-learn', 236889],
#  [2.2, True, False, False, nan, 74321],
#  [2.7, False, False, True, nan, 62593],
#  [1.2, True, False, False, 'Scikit-learn', 36288],
#  [1.0, True, False, False, 'PyTorch', 61302],
#  [1.8, False, False, False, nan, 68984],
#  [6.1, True, False, False, 'TensorFlow', 18858],
#  [4.5, True, False, True, 'Scikit-learn', 55418],
#  [1.1, True, False, True, 'TensorFlow', 614]]

# %%
survey[500:]
# Out:
# [[0.98, True, False, False, nan, 56213],
#  [3.3, False, False, False, nan, 57850],
#  [2.1, True, False, False, 'Scikit-learn', 62878],
#  [4.6, True, True, False, 'Scikit-learn', 53195],
#  [9.6, False, False, True, 'TensorFlow', 2312],
#  [1.3, False, True, True, nan, 163016],
#  [0.26, True, False, False, 'TensorFlow', 80274],
#  [9.6, True, True, False, nan, 34215],
#  [2.3, True, False, False, 'Scikit-learn', 68870],
#  [1.7, True, False, True, 'TensorFlow', 245],
#  [11.1, True, False, True, 'Scikit-learn', 92681],
#  [3.3, True, False, False, 'Scikit-learn', 72998],
#  [0.84, True, False, False, nan, 61803],
#  [3.7, True, False, False, 'Scikit-learn', 269443],
#  [1.5, True, False, True, nan, 58537],
#  [1.9, True, True, True, 'Scikit-learn', 160989],
#  [2.9, True, False, True, 'Keras', 21386],
#  [25.3, True, False, False, 'Keras', 262267],
#  [11.0, True, True, False, 'Scikit-learn', 40701],
#  [14.5, False, False, False, 'PyTorch', 14184],
# ...

# %%
grouped_data = df.groupby("Experience_Category")["compensation"].apply(list)

# separating list by assigning category
lessthan5 = grouped_data.get("< 5 Years") if "< 5 Years" in grouped_data else []
fiveto10 = grouped_data.get("5-10 Years") if "5-10 Years" in grouped_data else []
tento15 = grouped_data.get("10-15 Years") if "10-15 Years" in grouped_data else []
fifteento20 = grouped_data.get("15-20 Years") if "15-20 Years" in grouped_data else []
twentyto25 = grouped_data.get("20-25 Years") if "20-25 Years" in grouped_data else []
moretha25 = grouped_data.get("25+ Years") if "25+ Years" in grouped_data else []

# %%
print(lessthan5)
# Out:
# [74321, 62593, 36288, 61302, 68984, 55418, 614, 70564, 55525, 61005, 21, 620, 73527, 6992, 22311, 1377, 69174, 65937, 27856, 903, 50501, 482, 70407, 8690, 73454, 8075, 59151, 70112, 70183, 2521, 63616, 31516, 4187, 64405, 114807, 632, 61157, 1194, 56553, 75177, 28009, 67074, 50059, 74321, 671, 837, 2011, 62937, 685, 41615, 52572, 51856, 411, 152, 8181, 2708, 68412, 6141, 3864, 24393, 70796, 21055, 59167, 55882, 73802, 79803, 73043, 14298, 68805, 73664, 434, 10284, 67971, 58465, 64488, 7709, 1957, 4131, 62593, 107644, 1047, 59909, 68344, 54427, 70930, 50835, 11681, 70991, 52416, 288146, 186, 60065, 431, 45413, 4196, 61912, 67272, 70264, 264, 55482, 26, 250, 66025, 63754, 70448, 68964, 58574, 330, 64478, 62142, 60873, 27748, 239, 332, 51428, 50783, 226, 8015, 450, 348, 59456, 62821, 59666, 57673, 29472, 5119, 282, 106203, 74289, 74445, 67736, 785, 28073, 20390, 4791, 73319, 44491, 74799, 57207, 14370, 57816, 62513, 59687, 67959, 1337, 72317, 66163, 11165, 388, 12925, 3092, 13423, 4704,
# ...

# %%
sum(lessthan5)/len(lessthan5)
# Out:
# 45047.87484669119

# %%
sum(fiveto10)/len(fiveto10)
# Out:
# 59312.82033470161

# %%
cat = [lessthan5, fiveto10,tento15, fifteento20,twentyto25, moretha25]

for c in cat:
    print(sum(c)/len(c))
# Out:
# 45047.87484669119
# 59312.82033470161
# 80226.75581395348
# 75101.82694106642
# 103159.80432432433
# 90444.98512221042

# %%
df.shape
# Out:
# (25973, 7)

# %%
df.dtypes
# Out:
# experience_coding      float64
# python_user               bool
# r_user                    bool
# sql_user                  bool
# most_used               object
# compensation             int64
# Experience_Category     object
# dtype: object

# %%
df.head()
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation Experience_Category
# 0        124267          5-10 Years
# 1        236889         10-15 Years
# 2         74321           < 5 Years
# 3         62593           < 5 Years
# 4         36288           < 5 Years

# %%
df.iloc[0]
# Out:
# experience_coding               6.1
# python_user                    True
# r_user                        False
# sql_user                       True
# most_used              Scikit-learn
# compensation                 124267
# Experience_Category      5-10 Years
# Name: 0, dtype: object

# %%
df = df.copy()

df.iloc[:, 0] = df.iloc[:, 0].astype(float)
df.iloc[:, 5] = df.iloc[:, 5].astype(float)

df.iloc[:, 1] = df.iloc[:, 1].astype(str) == "TRUE"
df.iloc[:, 2] = df.iloc[:, 2].astype(str) == "TRUE"
df.iloc[:, 3] = df.iloc[:, 3].astype(str) == "TRUE"

df.iloc[:, 4] = df.iloc[:, 4].replace("None", None)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   experience_coding    25973 non-null  float64
#  1   python_user          25973 non-null  bool
#  2   r_user               25973 non-null  bool
#  3   sql_user             25973 non-null  bool
#  4   most_used            16835 non-null  object
#  5   compensation         25973 non-null  float64
#  6   Experience_Category  25973 non-null  object
# dtypes: bool(3), float64(2), object(2)
# memory usage: 887.9+ KB
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                1.0        False   False     False  Scikit-learn
# 1                1.0        False   False     False  Scikit-learn
# 2                1.0        False   False     False           NaN
# 3                1.0        False   False     False           NaN
# ...

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1        False   False     False  Scikit-learn
# 1                   12.3        False   False     False  Scikit-learn
# 2                    2.2        False   False     False           NaN
# 3                    2.7        False   False     False           NaN
# 4                    1.2        False   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9        False   False     False  Scikit-learn
# 25969                1.4        False   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4        False   False     False  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation Experience_Category
# 0          124267.0          5-10 Years
# 1          236889.0         10-15 Years
# ...

# %%
df.to_csv("updated_file.csv", index=False)

# %%
# Exporting Data
df.to_csv("cleaned_data.csv", index=False)

# Display final cleaned data
df.head()
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1        False   False     False  Scikit-learn
# 1               12.3        False   False     False  Scikit-learn
# 2                2.2        False   False     False           NaN
# 3                2.7        False   False     False           NaN
# 4                1.2        False   False     False  Scikit-learn
#
#    compensation Experience_Category
# 0      124267.0          5-10 Years
# 1      236889.0         10-15 Years
# 2       74321.0           < 5 Years
# 3       62593.0           < 5 Years
# 4       36288.0           < 5 Years

# %%
#dir(df)
